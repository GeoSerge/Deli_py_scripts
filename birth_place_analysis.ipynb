# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv('C:/Users/sgulbin/Work/Analysis/birth_place_analysis/accidents_minutes_birth_place.csv')

# %%
# Categorizing birth places

df.loc[df.birth_place.str.contains('ГОР', flags = re.IGNORECASE,regex = False)|df.birth_place.str.contains('гор', flags = re.IGNORECASE,regex = False)|
       df.birth_place.str.contains('ГОР.', flags = re.IGNORECASE,regex = False)|df.birth_place.str.contains('город', flags = re.IGNORECASE,regex = False)|
       df.birth_place.str.contains('ГОРОД', flags = re.IGNORECASE,regex = False)|df.birth_place.str.contains('г.', flags = re.IGNORECASE,regex = False)|
       df.birth_place.str.contains('Г.', flags = re.IGNORECASE,regex = False),'city'] = 1

df.loc[df.birth_place.str.contains('с.', flags = re.IGNORECASE,regex = False)|df.birth_place.str.contains('С.', flags = re.IGNORECASE,regex = False)|
       df.birth_place.str.contains('пос.', flags = re.IGNORECASE,regex = False)|df.birth_place.str.contains('ПОС.', flags = re.IGNORECASE,regex = False)|
       df.birth_place.str.contains('х.', flags = re.IGNORECASE,regex = False)|df.birth_place.str.contains('Х.', flags = re.IGNORECASE,regex = False)|
       df.birth_place.str.contains('пгт.', flags = re.IGNORECASE,regex = False)| df.birth_place.str.contains('ПГТ.', flags = re.IGNORECASE,regex = False)|
       df.birth_place.str.contains('пгт', flags = re.IGNORECASE,regex = False)| df.birth_place.str.contains('ПГТ', flags = re.IGNORECASE,regex = False),'country'] = 1

df.loc[df.birth_place.str.contains('Москва', flags = re.IGNORECASE, regex = False)|
       df.birth_place.str.contains('Петербург', flags = re.IGNORECASE,regex = False)|
       df.birth_place.str.contains('Ленинград', flags = re.IGNORECASE,regex = False)|
       df.birth_place.str.contains('Свердловск', flags = re.IGNORECASE,regex = False)|
       df.birth_place.str.contains('Екатеринбург', flags = re.IGNORECASE,regex = False)|
       df.birth_place.str.contains('Новосибирск', flags = re.IGNORECASE,regex = False)|
       df.birth_place.str.contains('Нижний Новгород', flags = re.IGNORECASE,regex = False)|
       df.birth_place.str.contains('Омск', flags = re.IGNORECASE,regex = False)|
       df.birth_place.str.contains('Красноярск', flags = re.IGNORECASE,regex = False)|
       df.birth_place.str.contains('Уфа', flags = re.IGNORECASE,regex = False)|
       df.birth_place.str.contains('Горький', flags = re.IGNORECASE,regex = False)|
       df.birth_place.str.contains('Самара', flags = re.IGNORECASE,regex = False)|
       df.birth_place.str.contains('Куйбышев', flags = re.IGNORECASE,regex = False)|
       df.birth_place.str.contains('Саратов', flags = re.IGNORECASE,regex = False)|
       df.birth_place.str.contains('Воронеж', flags = re.IGNORECASE,regex = False),'large_city'] = 1

df.loc[df.birth_place.str.contains('Москва', flags = re.IGNORECASE, regex = False)|
       df.birth_place.str.contains('Петербург', flags = re.IGNORECASE, regex = False)|
       df.birth_place.str.contains('Ленинград', flags = re.IGNORECASE,regex = False)|
       df.birth_place.str.contains('Свердловск', flags = re.IGNORECASE,regex = False)|
       df.birth_place.str.contains('Екатеринбург', flags = re.IGNORECASE,regex = False),'big3'] = 1

df.loc[df.birth_place.str.contains('Таджик', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Казах', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Груз', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Армен', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Азерб', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Киргиз', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Кыргыз', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Туркмен', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Узбек', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Дагест', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Ингуш', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Чеч', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Калмык', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Адыг', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Карач', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Кабард', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Осет', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Алания', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Tajik', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Kazakh', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Gruz', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Georg', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Armen', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Azerb', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Kyrgyz', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Turkmen', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Uzbek', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Тбилис', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Tbilis', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Кутаис', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Kutais', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Батум', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Batum', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Рустав', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Rustav', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Цхинвал', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Сухум', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Sukhum', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Ереван', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Yerevan', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Гюмри', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Gyumri', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Ванадзор', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Vanadzor', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Баку', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Baku', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Гяндж', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Gyuandzh', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Душанбе', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Dushanb', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Худжан', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Бохтар', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Ташкент', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Tashkent', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Самарканд', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Samarkand', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Андиж', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Andijon', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Наманган', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Namangan', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Бишкек', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Bishkek', flags = re.IGNORECASE)|
       df.birth_place.str.contains(' Ош', flags = re.IGNORECASE)|
       df.birth_place.str.contains(' Osh', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Джалал-Абад', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Жалал-Абад', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Jalal-Abad', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Каракол', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Karakol', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Ашхабад', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Ashgabat', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Туркменбаш', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Алма-Ата', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Almaty', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Шымкент', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Shymkent', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Караганда', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Karaganda', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Актобе', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Aktob', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Павлодар', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Pavlodar', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Махачкала', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Владикавказ', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Грозный', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Нальчик', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Пятигорск', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Хасавюрт', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Дербент', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Черкесск', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Назрань', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Каспийск', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Буйнакск', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Буденновск', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Урус-Мартан', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Избербаш', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Шали', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Гудермес', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Кизляр', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Моздок', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Карабулак', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Баксан', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Малгобек', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Аргун', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Кизилюрт', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Беслан', flags = re.IGNORECASE),'risky'] = 1

df.loc[df.birth_place.str.contains('Дагест', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Ингуш', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Чеч', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Калмык', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Махачкала', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Грозный', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Хасавюрт', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Дербент', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Черкесск', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Назрань', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Каспийск', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Буйнакск', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Буденновск', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Урус-Мартан', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Избербаш', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Шали', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Гудермес', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Кизляр', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Моздок', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Карабулак', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Баксан', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Малгобек', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Аргун', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Кизилюрт', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Элиста', flags = re.IGNORECASE)|
       df.birth_place.str.contains('Беслан', flags = re.IGNORECASE),'горцы'] = 1

df['city'] = df.city.fillna(0)
df['country'] = df.country.fillna(0)
df['large_city'] = df.large_city.fillna(0)
df['big3'] = df.big3.fillna(0)
df['risky'] = df.risky.fillna(0)
df['горцы'] = df['горцы'].fillna(0)

# %%
city = df.groupby('city').sum()

# %%
print(city)
# Out:
#            user_id  accidents_guilty_count  accidents_giulty_sum  \
# city
# 0.0   2.949986e+11                    1755           78767050.27
# 1.0   4.352566e+11                    1531           63512640.32
#
#       all_accidents_count  all_accidents_sum  paid_minutes         cost  \
# city
# 0.0                  3318       1.251319e+08   15538442.02  77736563.91
# 1.0                  2428       8.688650e+07   12009323.19  57498933.47
#
#       country  large_city  big3  risky  горцы
# city
# 0.0     348.0        83.0  76.0  189.0   83.0
# 1.0      48.0        19.0  17.0  328.0  104.0
